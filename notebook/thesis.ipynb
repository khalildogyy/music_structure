# %%
import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

mpl.rcParams['font.sans-serif'] = ['Microsoft YaHei']
mpl.rcParams['axes.unicode_minus'] = False

reports_files = os.listdir('../thesis/已完成调研表/')
reports_files
# Out:
# ['01-10胡文杰 调研表.xlsx',
#  '81-90边品三-调研表.xlsx',
#  '51-60徐静+调研表.xlsx',
#  '31-40魏一静 调研表.xlsx',
#  '41-50赵洁+调研表.xlsx',
#  '61-70王春婷 调研表.xlsx',
#  '71-80顾思芸-调研表.xlsx',
#  '61-70李静怡-调查表.xlsx',
#  '91-100徐正阳 调研表.xlsx',
#  '21-30裴建松 调研表.xlsx',
#  '71-80王皓雅-调研表.xlsx',
#  '41-50熊毓华-调研表.xlsx',
#  '01-10郑俊 调研表.xlsx',
#  '11-20冯凌冲-调研表.xlsx',
#  '31-40何钢锋-调研表.xlsx',
#  '81-90陈阳 调研表.xlsx',
#  '11-20李翔-调研表.xlsx',
#  '91-100程齐曼 调研表.xlsx',
#  '21-30陈苏怡-调研表.xlsx',
#  '51-60林之怡 调研表.xlsx']

# %%
data = []
for file in reports_files:
    temp = pd.read_excel('../thesis/已完成调研表/{}'.format(file))
    temp = temp.iloc[2:12, :5]
    temp.columns = ['音乐', '场景1', '场景2', '评价', '情感打分']
    data.append(temp)
data = pd.concat(data)
data
# Out:
#                                         音乐 场景1  场景2             评价 情感打分
# 2                        A_Long_Cold_Sting   1  NaN             欢快    9
# 3                         About_That_Oldie   5  NaN             蓬勃    7
# 4                       Ace - Back In Time   2    6             空灵    4
# 5                    Ace - Your Last Dream   3    6             空灵    4
# 6                         Acoustic_Circles   5  NaN             悠长    3
# 7            Andrew Applepie - Hit The Gas   4  NaN          雀跃，低沉    5
# 8                           Arms_of_Heaven   1  NaN             悠长    3
# 9                                 AT166_13   6    1          欢快，蓬勃    7
# 10    Backclash ft.Aarya - Never A Goodbye   3  NaN             悠长    5
# 11                         Boardroom_Theme   2    3          悠长，蓬勃    6
# 2                        Saddest_Beach.mp3   1  NaN          动感、欢快    8
# 3                           Safety_Net.mp3   6    1             欢乐    9
# 4                         Sand_Castles.mp3   5  NaN          兴奋、憧憬    7
# 5                 Sappheiros - Embrace.mp3   2    5           生机蓬勃    7
# 6   Sappheiros - Falling (ft. eSoreni).mp3   1    4          神秘、空灵    5
# 7                  Sappheiros - Lights.mp3   6    2             憧憬    8
# 8                Simon More - Emotions.mp3   5    2             轻快    6
# 9             Simon More - Happy Vibes.mp3   6    1             活泼    8
# 10             Simon Wood - No Feeling.mp3   5  NaN             欢快    7
# 11                    Siren - Run Away.mp3   1  NaN             浪漫    7
# 2                      JJD - Adventure.mp3   1    4          动感、摩登    7
# 3           Joakim Karud - Future Funk.mp3   6    5      慵懒、时尚的高冷感    3
# 4                 Joakim Karud - Waves.mp3   2    1             轻快    8
# 5                        Jorm - Broken.mp3   3    5          蓬勃、阳光    6
# 6                        Kid in Fourth.mp3   3    6          空灵、忧郁    2
# 7          Kontinuum - Lost feat.Savoi.mp3   1    4             开阔    7
# 8                    KSMK - Forget All.mp3   4    1          原始、粗犷    6
# 9                   KSMK - I'm K.S.M.K.mp3   4    3          神秘、壮烈    2
# 10           LAKEY INSPIRED - Going Up.mp3   6    1          慵懒、性感    5
# 11       LH039_08_Anything For You_KVH.mp3   5    6          田园、温馨    6
# ..                                     ...  ..  ...            ...  ...
# 2                   Skandr - Road Trip.mp3   6    5             空灵    7
# 3                     Skandr - Towards.mp3   3    2          空灵、冷淡    4
# 4                  Skylike - Limitless.mp3   1    6          雀跃、欢快    9
# 5                           Snack_Time.mp3   2    1          蓬勃、欢快    9
# 6              Sunny_Looks_Good_on_You.mp3   4    5             沉稳    3
# 7                        The_Papergirl.mp3   5    2             悠长    6
# 8                              Trapped.mp3   2  NaN             欢快    7
# 9                              Urchins.mp3   2  NaN          欢快、雀跃    9
# 10                  Web_Weaver_s_Dance.mp3   6    5             空灵    6
# 11                       Where_to_Walk.mp3   4    3             孤独    4
# 2      Dexter Britain-Charge Into 2015.mp3   2    3             空灵    7
# 3             Dizaro - Aurora Borealis.mp3   4    1             欢快    9
# 4                   Dizaro - FlashBack.mp3   5    1           节奏感强    9
# 5                      Dizaro - Hawaii.mp3   6    2             轻松    8
# 6                Dizaro - Night Stroll.mp3   3    4             空旷    6
# 7                      Dizaro - Safari.mp3   2    5             明亮    8
# 8                   Dizaro - YouMakeMe.mp3   2    1             灵性    8
# 9            Dj Quads - A coffee to go.mp3   4    3             寂寞    4
# 10                  Dyalla - I've Seen.mp3   2    6             明亮    7
# 11                 Dyalla - Oh My Life.mp3   2    6             轻松    7
# 2                      JJD - Adventure.mp3   1    4  电子感，节奏感、现代感较强    7
# 3           Joakim Karud - Future Funk.mp3   6    3             现代    5
# 4                 Joakim Karud - Waves.mp3   6    2             空灵    4
# 5                        Jorm - Broken.mp3   2    1         轻盈，潜水感    5
# 6                        Kid in Fourth.mp3   2    3             平静    3
# 7          Kontinuum - Lost feat.Savoi.mp3   4    1             蓬勃    6
# 8                    KSMK - Forget All.mp3   6    3          神秘，忧郁    2
# 9                   KSMK - I'm K.S.M.K.mp3   4    3          神秘、忧郁    1
# 10           LAKEY INSPIRED - Going Up.mp3   5    1             休闲    6
# 11       LH039_08_Anything For You_KVH.mp3   6    1          休闲、深情    6
#
# [200 rows x 5 columns]

# %%
# vlog下音乐的情感分布

ss = []
for i in range(10):
    ss.append(data[data['情感打分']==i].shape[0])
    print("score {}, num: {}".format(i, data[data['情感打分']==i].shape[0]))
    

fig, ax = plt.subplots(figsize=(4, 3))
# ax.bar(range(10), ss)
sns.distplot(list(data['情感打分'].values), bins=10, ax=ax)

ax.set_xticks(range(10))
ax.set_xticklabels(range(10), fontsize=12)
ax.set_xlabel(u'情 感 打 分', fontsize=12)
ax.set_yticks([0, 0.05, 0.1, 0.15, 0.2, 0.25])
ax.set_yticklabels([0, 0.05, 0.1, 0.15, 0.2, 0.25], fontsize=12)
ax.set_ylabel(u'占 比', fontsize=12)

plt.tight_layout()
# plt.savefig('/Users/JJjie/Downloads/情感打分统计.pdf')
plt.show()
# Out:
# score 0, num: 1
# score 1, num: 2
# score 2, num: 7
# score 3, num: 8
# score 4, num: 13
# score 5, num: 34
# score 6, num: 31
# score 7, num: 41
# score 8, num: 30
# score 9, num: 30
# /Users/JJjie/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# 不同的vlog场景，音乐情感分布
scens = ['大海 - 沙滩','森林 - 光束','雪地 - 结冰','沙漠 - 戈壁','草原 - 牛羊','天空 - 彩虹']

plotdata = []

for i in range(1, 7):
    temp1 = data[data['场景1']==i]
    temp2 = data[data['场景1']==i]
    tempd = list(temp1['情感打分'].values) + list(temp2['情感打分'].values) 
    temp = [[i, j] for i, j in zip(tempd, [scens[i-1]]*len(tempd))]
    plotdata.append(temp)
    
plotdata = pd.DataFrame(np.concatenate(plotdata), columns=['score', 'scene'])
plotdata['score'] = plotdata['score'].astype(float)
# plotdata

fig, ax = plt.subplots(figsize=(15, 5))
sns.boxplot(x="scene", y="score", data=plotdata, palette='muted', width=0.3, ax=ax)
sns.despine(left=True)

ax.set_ylabel(u'情 感 打 分', fontsize=16)
ax.set_yticklabels(np.arange(0, 10), fontsize=14)
ax.set_xlabel(u'场 景', fontsize=16)
ax.set_xticklabels(scens, fontsize=14, rotation=0)

plt.show()

# %%
# 统计词频

import collections
from wordcloud import WordCloud

def getwords(dataset):
    def split(word):
        s = ','
        if ',' in word:
            s = ','
        elif '，' in word:
            s = '，'
        elif '、' in word:
            s = '、'
        return word.split(s)

    words0 = []
    for w in data['评价']:
         words0 += split(w)
    words = []
    for w in words0:
        if len(w) == 4:
            words += [w[:2], w[2:]]
        else:
            words += split(w)
    return words
    
words = getwords(data['评价'])

# 词频统计
word_counts = collections.Counter(words) # 对分词做词频统计
print (word_counts.most_common(10)) # 输出检查

# 词频展示
wc = WordCloud(collocations=True, 
               font_path=r'/Library/Fonts/Microsoft/SimHei.ttf', 
               width=1400, 
               height=960, 
               margin=2).generate(" ".join(words))
plt.imshow(wc) # 显示词云
plt.axis('off') # 关闭坐标轴
plt.show() # 显示图像
# Out:
# [('欢快', 36), ('空灵', 20), ('蓬勃', 18), ('雀跃', 17), ('悠长', 11), ('放松', 7), ('低沉', 6), ('雄壮', 6), ('轻松', 6), ('轻快', 5)]

# %%
for i in range(1, 7):
    print(scens[i-1])
    temp = data[data['场景1']==i]
    words = getwords(temp['评价'])

    # 词频展示
    wc = WordCloud(collocations=True, 
                   font_path=r'/Library/Fonts/Microsoft/SimHei.ttf', 
                   width=1400, 
                   height=960, 
                   margin=2).generate(" ".join(words))
    plt.imshow(wc) # 显示词云
    plt.axis('off') # 关闭坐标轴
    plt.show() # 显示图像
# Out:
# 大海 - 沙滩
# 森林 - 光束
# 雪地 - 结冰
# 沙漠 - 戈壁
# 草原 - 牛羊
# 天空 - 彩虹
